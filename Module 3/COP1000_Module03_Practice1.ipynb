# %%
number1 = 18
number2 = 5

print("Addition:", number1 + number2)
print("Subtraction:", number1 - number2)
print("Multiplication:", number1 * number2)
print("Division:", number1 / number2)
print("Floor Division:", number1 // number2)
print("Modulus:", number1 % number2)
print("Exponent:", number1 ** number2)
# Out:
# Addition: 23
# Subtraction: 13
# Multiplication: 90
# Division: 3.6
# Floor Division: 3
# Modulus: 3
# Exponent: 1889568

# %%
age = 21

print(age == 21)
print(age != 18)
print(age > 18)
print(age < 30)
print(age >= 21)
print(age <= 20)
# Out:
# True
# True
# True
# True
# True
# False

# %%
# print(10 > 5) would be True because 10 is greater than 5.
# print(8 == 8) would be True because 8 is equal to 8
# print(7 != 7) would be False because 7 IS equal to 7.
# print(4 >= 9) would be False because 4 smaller than 9 also not equal to.
# print(15 < 20) would be true because 15 is less than 20.

# %%
print(10 > 5)
print(8 == 8)
print(7 != 7)
print(4 >= 9)
print(15 < 20)
# Out:
# True
# True
# False
# False
# True

# %%
#### SIDE NOTES ####
# I think it's weird "!" is within the problem.

# %%
age = 22
has_id = True

resultA = age >= 18 and has_id
print(resultA)

resultB = age >= 18 or has_id
print(resultB)

resultC = not has_id
print(resultC)
# Out:
# True
# True
# False

# %%
temperature = 75

e1 = temperature > 70
print("Greater than 70:", e1)
e2 = temperature < 90
print("Less than 90:", e2)
e3 = 70 <= temperature <= 80
print("Between 70 and 90:", e3)
e4 = temperature< 60 or temperature > 85
print("Outside range of 60 thru 85:", e4)
# Out:
# Greater than 70: True
# Less than 90: True
# Between 70 and 90: True
# Outside range of 60 thru 85: False

# %%
age = 19
credits_completed = 30

age_met = age >= 18
creds_met = credits_completed >= 24
all_met = age_met and creds_met

print(f" Age Requirements Met: {age_met}")
print(f" Credit Requirments Met: {creds_met}")
print(f" All Requirments Met: {age_met and creds_met}")
# Out:
#  Age Requirements Met: True
#  Credit Requirments Met: True
#  All Requirments Met: True
