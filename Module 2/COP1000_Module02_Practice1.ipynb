# %%
first_name = "Hunter"
age = 26
gpa = 3.2
is_student = True

print(type(first_name))
print(type(age))
print(type(gpa))
print(type(is_student))

ogscore = 75
newscore = 90
print(ogscore, newscore)

number1 = 20
number2 = 5
print(number1 + number2)
print(number1 - number2)
print(number1 * number2)
print(number1 / number2)

first_name = "Hunter"
last_name = "Prince"
career = "plumber"
output_sentence = f"My name is {first_name} {last_name}, and im interested in becoming a {career}."
print(output_sentence)

name = "Josh"
course = "COP1000"
grade = 99.9
assignments_completed = 89
enrolled = True

print("StudentRecord")
print(f"Name: {name}")
print(f"Course: {course}")
print(f"Grade: {grade}")
print(f"Assignments Completed: {assignments_completed}")
print(f"Currently Enrolled: {enrolled}")
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 75 90
# 25
# 15
# 100
# 4.0
# My name is Hunter Prince, and im interested in becoming a plumber.
# StudentRecord
# Name: Josh
# Course: COP1000
# Grade: 99.9
# Assignments Completed: 89
# Currently Enrolled: True
